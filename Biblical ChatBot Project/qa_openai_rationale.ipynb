# %% [markdown]
# # Setup

# %%
# !pip install openai py-readability-metrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 13.6 MB/s eta 0:00:00
# ...

# %%
import openai
from readability import Readability
import nltk

# %% [markdown]
# # Model & Response

# %%
context = '''
The sons of Gomer were Askenaz, Riphath, and Togarmah.
'''

question = '''
Who was the father of Askenaz?
'''

# %%
openai.api_key = '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'

response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
        {'role': 'system', 'content': 'You are a helpful bible question answer assistant who provides rationale for their answers.'},
        {'role': 'user', 'content': 'Noah went out along with his sons, his wife, and his sons\' wives.\nWho went out with his sons, his wife, and his sons\' wives?'},
        {'role': 'assistant', 'content': 'Read the instruction: Who went out with his sons, his wife, and his sons\' wives?"\nAnalyze the input to gather relevant information: "Noah went out along with his sons, his wife, and his sons\' wives."\nIdentify the mention of Noah in the input.\nNote the statement that Noah went out with his sons, his wife, and his sons\' wives.\nDetermine that the instruction is asking for the person who went out with his sons, his wife, and his sons\' wives.\nConnect the information from the input to the instruction and conclude that "Noah" is the person who fits the criteria.\nProvide the response "Noah" as it correctly identifies the person who went out with his sons, his wife, and his sons\' wives.\nThe answer is: Noah.'},
        {'role': 'user', 'content': 'The name of the third river is Tigris; it runs along the east side of Assyria. The fourth river is the Euphrates.\nWhat country does the Tigris run along?'},
        {'role': 'assistant', 'content': 'Read the instruction: "What country does the Tigris run along?"\nAnalyze the input to gather relevant information: "The name of the third river is Tigris; it runs along the east side of Assyria. The fourth river is the Euphrates."\nIdentify the mention of the Tigris river in the input.\nNote the statement that the Tigris river runs along the east side of Assyria.\nDetermine that the instruction is asking for the country that the Tigris river runs along.\nConnect the information from the input to the instruction and conclude that "Assyria" is the country the Tigris river runs along.\nProvide the response "Assyria" as it correctly identifies the country associated with the Tigris river.\nThe answer is: Assyria.'},
        {'role': 'user', 'content': f'{context}\n{question}'}
    ]
)

# %%
response = response['choices'][0]['message']['content']
print(response)
# Out:
# Read the instruction: "Who was the father of Askenaz?"
# Analyze the input to gather relevant information: "The sons of Gomer were Askenaz, Riphath, and Togarmah."
# Identify the mention of Askenaz in the input.
# Note that Askenaz is listed as one of the sons of Gomer.
# Determine that the instruction is asking for the father of Askenaz.
# Connect the information from the input to the instruction and conclude that "Gomer" was the father of Askenaz.
# Provide the response "Gomer" as it correctly identifies the father of Askenaz.
# The answer is: Gomer.

# %% [markdown]
# ## Translations

# %%
translation_data = openai.Completion.create(
    model = 'text-davinci-003',
    prompt = f'Translate this into French, German, and Spanish:\n```{response}```',
    temperature = 0.3,
    max_tokens = 1000
)

# %%
translations = translation_data.choices[0]['text']
split_translations = translations.split('\n\n')
split_translations.pop(0)

# %%
french = split_translations[0]
german = split_translations[1]
spanish = split_translations[2]

# %%
print(french)
print(german)
print(spanish)
# Out:
# French:
# Lisez l'instruction: "Qui était le père d'Askenaz?"
# Analyser l'entrée pour recueillir des informations pertinentes: "Les fils de Gomer étaient Askenaz, Riphath et Togarmah".
# Identifier la mention d'Askenaz dans l'entrée.
# Notez qu'Askenaz est énuméré comme l'un des fils de Gomer.
# Déterminer que l'instruction demande le père d'Askenaz.
# Relier les informations de l'entrée à l'instruction et conclure que "Gomer" était le père d'Askenaz.
# Fournir la réponse "Gomer" car elle identifie correctement le père d'Askenaz.
# La réponse est: Gomer.
# German:
# Lesen Sie die Anweisung: "Wer war der Vater von Askenaz?"
# Analysieren Sie die Eingabe, um relevante Informationen zu sammeln: "Die Söhne von Gomer waren Askenaz, Riphath und Togarmah".
# Identifizieren Sie die Erwähnung von Askenaz in der Eingabe.
# Beachten Sie, dass Askenaz als einer der Söhne von Gomer aufgeführt ist.
# Bestimmen Sie, dass die Anweisung nach dem Vater von Askenaz fragt.
# ...

# %% [markdown]
# # Readability Metrics
# In order to make sure our data is usable to more people, we need to make sure that the reading level is suitable for people without advanced degrees or coding experience.
# Descriptions of the various measurements taken from [here](https://pypi.org/project/py-readability-metrics/).

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# need to add words to get to the minimum of 100
while len(response.split(' ')) < 100:
  response = response + ' <pad>'

# %%
response
# Out:
# 'Read the instruction: "Who was the father of Askenaz?"\nAnalyze the input to gather relevant information: "The sons of Gomer were Askenaz, Riphath, and Togarmah."\nIdentify the mention of Askenaz in the input.\nNote the statement that Askenaz is one of the sons of Gomer.\nDetermine that the instruction is asking for the father of Askenaz.\nConnect the information from the input to the instruction and conclude that "Gomer" is the father of Askenaz as per the mentioned genealogy.\nProvide the response "Gomer" as it correctly identifies the father of Askenaz.\nThe answer is: Gomer. <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>'

# %%
r = Readability(response)

# %% [markdown]
# ## Flesch-Kincaid Grade Level

# %% [markdown]
# The U.S. Army uses Flesch-Kincaid Grade Level for assessing the difficulty of technical manuals. The commonwealth of Pennsylvania uses Flesch-Kincaid Grade Level for scoring automobile insurance policies to ensure their texts are no higher than a ninth grade level of reading difficulty. Many other U.S. states also use Flesch-Kincaid Grade Level to score other legal documents such as business policies and financial forms.
#
# Note: readable.com suggests a grade level score of 8 for general public accessibility. It also recommends Flesch-Kincaid as it is the most general formula and not meant for a specific domain of literature.

# %%
fk = r.flesch_kincaid()
print(fk.score)
print(fk.grade_level)
# Out:
# 8.228467432950193
# 8

# %% [markdown]
# ## Dale-Chall Formula

# %% [markdown]
# The Dale-Chall Formula is an accurate readability formula for the simple reason that it is based on the use of familiar words, rather than syllable or letter counts. Reading tests show that readers usually find it easier to read, process and recall a passage if they find the words familiar.

# %% [markdown]
# Note: This method seems to have higher scores regardless of if foreign names are present or not.

# %%
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
def replace_proper_names(text):
    words = word_tokenize(text)
    tagged_words = pos_tag(words)
    
    replaced_words = []
    for word, tag in tagged_words:
        if tag == 'NNP':
            replaced_words.append('[NAME]')
        else:
            replaced_words.append(word)
    
    replaced_text = ' '.join(replaced_words)
    
    return replaced_text

# %%
no_name_response = replace_proper_names(response)

# %%
nnr = Readability(no_name_response)
dc =nnr.dale_chall()
print(dc.score)
print(dc.grade_levels)
# Out:
# 12.283536461704424
# ['college_graduate']

# %% [markdown]
# ## Linsear Write

# %% [markdown]
# Linsear Write is a readability metric for English text, purportedly developed for the United States Air Force to help them calculate the readability of their technical manuals.
#
# Note: seems pretty similar to F-K above, but has a focus on simple writing style and word difficulty.

# %%
lw = r.linsear_write()
print(lw.score)
print(lw.grade_level)
# Out:
# 7.888888888888889
# 8
